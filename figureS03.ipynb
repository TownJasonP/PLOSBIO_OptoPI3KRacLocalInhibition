# %%
import os
import math
import json
import datetime
import numpy as np
import pandas as pd

from tifffile import tifffile

from skimage import morphology, filters, transform, measure
from skimage.feature import peak_local_max

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mp
from matplotlib import cm

from scipy import stats, optimize
from scipy.interpolate import interp1d
from scipy.signal import savgol_filter
from scipy.stats import levene
from scipy.ndimage import center_of_mass

def plane(X, a, b, c):
    '''equation for a plane for approximating background subtractions in cropped microscope images'''
    return(a*X[0] + b * X[1] + c)


class simpleStimData:
    '''
    class for interpreting data saved on the microscope during live-cell tracking and computer-
    generated opto experiments. Contains information about the state of the microscope, the images
    themselves, and has methods for background subtraction and some basic processing
    '''
    def __init__(self, folderpath):
        self.folderpath = folderpath
        self.xpath_rot = []
        self.ypath_rot = []
        self.assay_type = ''
        self.get_image_paths()
        self.get_stage_data()
        self.transform_mats = self.get_transformation_matrices()
        self.get_image_stacks()
        self.background_subtraction()
        
    def get_image_paths(self):
        
        # collect image paths within the folder
        try:
            im_path_list = np.sort([self.folderpath + '/' + i for i in np.sort(os.listdir(self.folderpath))])
        except:
            im_path_list = np.sort([self.folderpath + '/' + i.decode('ascii') for i in np.sort(os.listdir(self.folderpath))])

        self.ch0_path_list = np.sort([i for i in im_path_list if 'channel000' in i])
        self.ch1_path_list = np.sort([i for i in im_path_list if 'channel001' in i])
        self.ch2_path_list = np.sort([i for i in im_path_list if 'channel002' in i])
        self.ch3_path_list = np.sort([i for i in im_path_list if 'channel003' in i])
        self.ch4_path_list = np.sort([i for i in im_path_list if 'channel004' in i])
        self.ch5_path_list = np.sort([i for i in im_path_list if 'channel005' in i])
        self.ch6_path_list = np.sort([i for i in im_path_list if 'channel006' in i])
        
    def get_stage_data(self):
        
        x_stage_sequence = []
        y_stage_sequence = []

        for i in range(len(self.ch0_path_list)):
            with tifffile.TiffFile(self.ch0_path_list[i]) as temptif:

                # collect stage coordinates from tiff metadata
                xval = float(temptif.shaped_metadata[0]['stage_x_pos'])
                yval = float(temptif.shaped_metadata[0]['stage_y_pos'])

                x_stage_sequence.append(xval)
                y_stage_sequence.append(yval)

        # convert to numpy arrays to make translation and rotation a little easier
        self.x_stage_sequence = np.array(x_stage_sequence)
        self.y_stage_sequence = np.array(y_stage_sequence)

        # center paths on the moment of stimulation
        x_translated = self.x_stage_sequence - self.x_stage_sequence[10] 
        y_translated = self.y_stage_sequence - self.y_stage_sequence[10]

        # calculate the initial direction of the cell in the first ten frames
        self.theta = np.arctan2(-np.average(np.diff(y_translated[:10])), np.average(np.diff(x_translated[:10])))

        # convert into 
        rho = np.hypot(x_translated, y_translated)
        phi = np.arctan2(-y_translated, x_translated) - self.theta  + math.pi/2

        self.x_rotated = rho * np.cos(phi)
        self.y_rotated = rho * np.sin(phi)
        self.centering_x = self.x_stage_sequence[10]
        self.centering_y = self.y_stage_sequence[10]
        

    def get_transformation_matrices(self):
        # this lets us rotate and transform the microscopy data to standardize it based on cell movement
        
        temptif = tifffile.TiffFile(self.ch0_path_list[0])
        centering_matrix = np.array([[1, 0, -200],[0, 1, -200],[0, 0, 1]])
        affine_matrix = np.vstack([np.array([float(i) for i in temptif.shaped_metadata[0]['PixelSizeAffine'].split(';')]).reshape(2, 3), np.array([0, 0, 1])])
        rotation_matrix = np.array([[np.cos(self.theta), -np.sin(self.theta), 0], [np.sin(self.theta), np.cos(self.theta), 0], [0, 0, 1]])
        transformation_matrix = np.matmul(affine_matrix, centering_matrix)
        transformation_matrix = np.matmul(rotation_matrix, transformation_matrix)


        transformation_matrices = []
        for t in range(len(self.x_stage_sequence)):

            xt = (self.x_stage_sequence[t] - self.centering_x)
            yt = (self.y_stage_sequence[t] - self.centering_y)

            xr, yr, placeholder = np.matmul(rotation_matrix, np.array([xt, yt, 0]))
            translation_matrix = np.array([[1, 0, xr],[0, 1, yr],[0, 0, 1]])

            tm = np.matmul(translation_matrix, transformation_matrix)

            transformation_matrices.append(tm.copy())

        return(transformation_matrices)

        
    def get_image_stacks(self):
        
        # make some containers for the pixel intensity information
        self.ch0_stack = np.zeros((len(self.ch0_path_list), 400, 400))
        self.ch1_stack = np.zeros((len(self.ch1_path_list), 400, 400))
        self.ch2_stack = np.zeros((len(self.ch2_path_list), 400, 400))
        self.ch3_stack = np.zeros((len(self.ch3_path_list), 400, 400))
        self.ch4_stack = np.zeros((len(self.ch4_path_list), 400, 400))
        self.ch5_stack = np.zeros((len(self.ch5_path_list), 400, 400))
        self.ch6_stack = np.zeros((len(self.ch6_path_list), 400, 400))
        
        # and for elapsed time
        self.ch0_times = np.zeros(len(self.ch0_path_list))
        self.ch1_times = np.zeros(len(self.ch1_path_list))
        self.ch2_times = np.zeros(len(self.ch2_path_list))
        self.ch3_times = np.zeros(len(self.ch3_path_list))
        self.ch4_times = np.zeros(len(self.ch4_path_list))
        self.ch5_times = np.zeros(len(self.ch5_path_list))
        self.ch6_times = np.zeros(len(self.ch6_path_list))
        
        for i in range(len(self.ch0_path_list)):
            with tifffile.TiffFile(self.ch0_path_list[i]) as temptif:
                self.ch0_stack[i] = temptif.asarray()
                try:
                    self.ch0_times[i] = np.round(float(temptif.shaped_metadata[0]['elapsed_time_s']), 1)
                except:
                    pass

        for i in range(len(self.ch1_path_list)):
            with tifffile.TiffFile(self.ch1_path_list[i]) as temptif:
                self.ch1_stack[i] = temptif.asarray()
                try:
                    self.ch1_times[i] = np.round(float(temptif.shaped_metadata[0]['elapsed_time_s']), 1)
                except:
                    pass
                
        for i in range(len(self.ch2_path_list)):
            with tifffile.TiffFile(self.ch2_path_list[i]) as temptif:
                self.ch2_stack[i] = temptif.asarray()
                try:
                    self.ch2_times[i] = np.round(float(temptif.shaped_metadata[0]['elapsed_time_s']), 1)
                except:
                    pass
                
        for i in range(len(self.ch3_path_list)):
            with tifffile.TiffFile(self.ch3_path_list[i]) as temptif:
                self.ch3_stack[i] = temptif.asarray()
                try:
                    self.ch3_times[i] = np.round(float(temptif.shaped_metadata[0]['elapsed_time_s']), 1)
                except:
                    pass
                
        for i in range(len(self.ch4_path_list)):
            with tifffile.TiffFile(self.ch4_path_list[i]) as temptif:
                self.ch4_stack[i] = temptif.asarray()
                try:
                    self.ch4_times[i] = np.round(float(temptif.shaped_metadata[0]['elapsed_time_s']), 1)
                except:
                    pass
                
        for i in range(len(self.ch5_path_list)):
            with tifffile.TiffFile(self.ch5_path_list[i]) as temptif:
                self.ch5_stack[i] = temptif.asarray()
                try:
                    self.ch5_times[i] = np.round(float(temptif.shaped_metadata[0]['elapsed_time_s']), 1)
                except:
                    pass
                
        for i in range(len(self.ch6_path_list)):
            with tifffile.TiffFile(self.ch6_path_list[i]) as temptif:
                self.ch6_stack[i] = temptif.asarray()
                try:
                    self.ch6_times[i] = np.round(float(temptif.shaped_metadata[0]['elapsed_time_s']), 1)
                except:
                    pass
        
        
    def get_transformed_xy_coords(self, timepoint):
        xx, yy = np.meshgrid(np.arange(400), np.arange(400))
        zz = np.ones_like(xx)

        coords = np.array([xx.ravel(), yy.ravel(), zz.ravel()])
        y_um, x_um, placeholder = np.matmul(self.transform_mats[timepoint], coords)
        
        return(x_um.reshape(400,400), y_um.reshape(400,400))

    
    def background_subtraction(self):
        # fit a plane to the median of non-cell signal over the course of the experiment
        bgstack_ch0 = []
        bgstack_ch1 = []
        for T in range(len(self.ch0_stack)):
            bg_ch0 = self.ch0_stack[T].copy()
            bg_ch1 = self.ch1_stack[T].copy()
            cell = self.ch3_stack[T] == 1
            cell = morphology.binary_dilation(cell, selem = morphology.disk(10))
            bg_ch0[cell] = np.nan
            bg_ch1[cell] = np.nan
            bgstack_ch0.append(bg_ch0)
            bgstack_ch1.append(bg_ch1)

        measured_bg_ch0 = np.nanmedian(bgstack_ch0, axis = 0)
        measured_bg_ch1 = np.nanmedian(bgstack_ch1, axis = 0)
        xx, yy = np.meshgrid(np.arange(400), np.arange(400))
        zz_ch0 = measured_bg_ch0
        zz_ch1 = measured_bg_ch1

        xx = xx[np.isfinite(zz_ch0)]
        yy = yy[np.isfinite(zz_ch0)]
        zz_ch0 = zz_ch0[np.isfinite(zz_ch0)]
        zz_ch1 = zz_ch1[np.isfinite(zz_ch1)]

        X = np.array([xx, yy])
        popt_ch0, pcov = optimize.curve_fit(plane, X, zz_ch0, p0 = [1, 1, 500])
        popt_ch1, pcov = optimize.curve_fit(plane, X, zz_ch1, p0 = [1, 1, 500])
        
        X = np.meshgrid(np.arange(400), np.arange(400))
        self.ch0_estimated_bg = plane(X, popt_ch0[0], popt_ch0[1], popt_ch0[2])
        self.ch1_estimated_bg = plane(X, popt_ch1[0], popt_ch1[1], popt_ch1[2])
    
    def calculate_global_dynamics(self):
        ch0_avg = []
        ch1_avg = []
        
        for T in range(len(self.ch0_stack)):
            try:
                ch0_F = np.average((self.ch0_stack[T] - self.ch0_estimated_bg)[self.ch3_stack[T] > 0])
                ch1_F = np.average((self.ch1_stack[T] - self.ch1_estimated_bg)[self.ch3_stack[T] > 0])
                
            except:
                ch0_F = np.nan
                ch1_F = np.nan
                
            ch0_avg.append(ch0_F)
            ch1_avg.append(ch1_F)
            
        self.ch0_dynamics = np.array(ch0_avg)
        self.ch1_dynamics = np.array(ch1_avg)
        
    def calculate_frontbackSignals(self):
        ch0_frontback = []
        ch1_frontback = []

        for T in range(len(self.ch0_stack)):

            try:
                xx, yy = np.meshgrid(np.arange(400), np.arange(400))
                xx -= 200
                yy -= 200

                regions = measure.regionprops((self.ch3_stack[T] > 0).astype(int), intensity_image = self.ch1_stack[T] - self.ch1_estimated_bg)
                yc, xc = regions[0].centroid
                yw, xw = regions[0].weighted_centroid
                direction = np.arctan2(yw - yc, xw - xc)

                dist = np.hypot(xx, yy)
                angle = np.arctan2(yy, xx)
                dmap = dist * np.cos(angle - direction)
                dmap[self.ch3_stack[T] == 0] = np.nan

                frontloc = np.unravel_index(np.nanargmax(dmap), dmap.shape)
                xx, yy = np.meshgrid(np.arange(400), np.arange(400))
                dmap2 = np.hypot(yy - frontloc[0], xx - frontloc[1])
                x, y = dmap2[self.ch3_stack[T] > 0], self.ch0_stack[T][self.ch3_stack[T] > 0] - self.ch0_estimated_bg[self.ch3_stack[T] > 0]
                bs, be, bn = stats.binned_statistic(x, y, statistic = 'mean', bins = np.arange(0, 101))

                y2 = self.ch1_stack[T][self.ch3_stack[T] > 0] - self.ch1_estimated_bg[self.ch3_stack[T] > 0]
                bs2, be, bn = stats.binned_statistic(x, y2, statistic = 'mean', bins = np.arange(0, 101))

            except:
                bs = np.zeros(100) + np.nan
                bs2 = np.zeros(100) + np.nan

            ch0_frontback.append(bs)
            ch1_frontback.append(bs2)
            
        self.ch0_frontback = ch0_frontback
        self.ch1_frontback = ch1_frontback
        
    def get_angular_representation(self):
        
        self.ch0_ring = []
        self.ch1_ring = []
        self.ch2_ring = []
        
        self.ringstack = []

        pixch0 = []
        pixch1 = []
        for T in range(10):
            if np.sum(self.ch3_stack[T]) > 0:
                vals = self.ch0_stack[T][self.ch3_stack[T] > 0] - self.ch0_estimated_bg[self.ch3_stack[T] > 0]
                pixch0 = np.hstack([pixch0, vals])
                vals = self.ch1_stack[T][self.ch3_stack[T] > 0] - self.ch1_estimated_bg[self.ch3_stack[T] > 0]
                pixch1 = np.hstack([pixch1, vals])
        ch0_basal = np.average(pixch0)
        ch1_basal = np.average(pixch1)


        for T in range(len(self.ch3_stack)):
            try:
                outer = self.ch3_stack[T] > 0

                inner = morphology.binary_erosion(outer, selem = morphology.disk(15))
                ring = morphology.binary_erosion(outer, selem = morphology.disk(1)) & ~inner

                self.ringstack.append(ring)

                yc, xc = center_of_mass(self.ch3_stack[T])

                yy, xx = np.where(ring)
                A = np.arctan2(-(yy - yc), (xx - xc)) + self.theta
                A = np.arctan2(-np.sin(A), np.cos(A))

                F = self.ch0_stack[T][ring] - self.ch0_estimated_bg[ring]
                F /= ch0_basal
                bs, be, bn = stats.binned_statistic(A, F, statistic = 'mean', bins = np.linspace(-math.pi, math.pi, 101))
                self.ch0_ring.append(bs)

                F = self.ch1_stack[T][ring] - self.ch1_estimated_bg[ring]
                F /= ch1_basal
                bs, be, bn = stats.binned_statistic(A, F, statistic = 'mean', bins = np.linspace(-math.pi, math.pi, 101))
                self.ch1_ring.append(bs)

                bs, be, bn = stats.binned_statistic(A, self.ch2_stack[T][ring], statistic = 'mean', bins = np.linspace(-math.pi, math.pi, 101))
                self.ch2_ring.append(bs)


            except:
                self.ch0_ring.append(np.zeros(100) + np.nan)
                self.ch1_ring.append(np.zeros(100) + np.nan)
                self.ch2_ring.append(np.zeros(100) + np.nan)
            
        self.ch0_ring = np.fliplr(self.ch0_ring)
        self.ch1_ring = np.fliplr(self.ch1_ring)
        self.ch2_ring = np.fliplr(self.ch2_ring)

    

def get_tform_mat(input_bin, theta):
    '''
    Given a binary image representing a single cell and an angle,
    generate the transformation matrix that allows for rotation about
    the center of mass of the binary input by theta
    '''

    input_lbl = measure.label(input_bin)
    region = measure.regionprops(input_lbl)[0]
    y_c, x_c = region.centroid

    c = np.cos(theta)
    s = np.sin(theta)
    t_y = -y_c
    t_x = -x_c

    # translation followed by rotation
    tsl_mat = np.array([[1, 0, 0], [0, 1, 0], [t_x, t_y, 1]])
    rot_mat = np.array([[c, -s, 0],[s, c, 0],[0, 0, 1]])

    tfm_mat = np.matmul(tsl_mat, rot_mat)

    return(tfm_mat)

def get_lateral_points(input_bin, theta):
    '''
    Given a binary image representing the location of a single cell
    and the corresponding fluorescence image, calculate a polarity vector
    based on the fluorescence image and locate the lateral sides of the cell
    relative to the polarity vector
    '''

    tfm_mat = get_tform_mat(input_bin, theta)

    # collect coordinates and transform
    all_ys, all_xs = np.where(input_bin)
    all_zs = np.ones_like(all_ys)

    coords_initial = np.array([all_xs, all_ys, all_zs]).T
    coords_tformed = np.matmul(coords_initial, tfm_mat)

    x, y, z = coords_tformed.T

    # look for furthest lateral sides in transformed coordinates
    ymax = np.max(y[(x < 1) & (x > -1)])
    ymin = np.min(y[(x < 1) & (x > -1)])

    # apply inverse transformation to lateral coordinates
    x_R, y_R, placeholder = np.matmul(np.array([0, ymin, 1]), np.linalg.inv(tfm_mat))
    x_L, y_L, placeholder = np.matmul(np.array([0, ymax, 1]), np.linalg.inv(tfm_mat))

    return([x_R, y_R, x_L, y_L])

# %%
# Collect paths to data in memory - this is needed to run most code blocks below
# select unique identifiers of the various test conditions for folders inside parent_dir

different_conditions = ['_none_', '_side_', '_front_', '_back_', '_global_']

DATA = []
for condition in different_conditions:
    print(f'finding paths containing: "{condition}"' + '\n')
    # collect local list of paths to experiments to pool together for display
    for i in os.listdir('data/simpleStimData/'):
        if (condition in i):
            print(i)
            DATA.append('data/simpleStimData/' + i)

DATA = np.array(DATA)
for condition in different_conditions:
    print(condition, np.sum([condition in i for i in DATA]))
# Out:
# finding paths containing: "_none_"
#
# 220307_KWC_35-52-97_simpleStimScreen_none_50000_Intensity_001
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_000
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_015
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_001
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_012
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_006
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_002
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_012
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_007
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_003
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_012
# 220214_KWC_35-52-97_simpleStimScreen_none_50000_Intensity_000
# 220228_KWC_35-52-97_simpleStimScreen_well2_none_50000_Intensity_001
# 220228_KWC_35-52-97_simpleStimScreen_none_50000_Intensity_000
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_013
# 220307_KWC_35-52-97_simpleStimScreen_none_50000_Intensity_005
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_015
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_000
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_002
# 220307_KWC_35-52-97_simpleStimScreen_none_50000_Intensity_004
# 220228_KWC_35-52-97_simpleStimScreen_well2_none_50000_Intensity_000
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_009
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_006
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_002
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_010
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_007
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_000
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_001
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_014
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_010
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_004
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_010
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_003
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_003
# 220307_KWC_35-52-97_simpleStimScreen_none_50000_Intensity_000
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_008
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_014
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_004
# 220307_KWC_35-52-97_simpleStimScreen_none_50000_Intensity_002
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_011
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_009
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_005
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_011
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_008
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_009
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_007
# 220307_KWC_35-52-97_simpleStimScreen_none_50000_Intensity_003
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_005
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_001
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_none_50000_Intensity_008
# finding paths containing: "_side_"
#
# 220214_KWC_35-52-97_simpleStimScreen_side_50000_Intensity_000
# 220228_KWC_35-52-97_simpleStimScreen_side_50000_Intensity_000
# 220725_KWC_35-52-97_mcPak_Assays_side_50000_Intensity_005
# 220307_KWC_35-52-97_simpleStimScreen_side_50000_Intensity_003
# 220214_KWC_35-52-97_simpleStimScreen_side_50000_Intensity_001
# 220725_KWC_35-52-97_mcPak_Assays_side_50000_Intensity_001
# 220725_KWC_35-52-97_mcPak_Assays_side_50000_Intensity_003
# 220725_KWC_35-52-97_mcPak_Assays_side_50000_Intensity_004
# 220725_KWC_35-52-97_mcPak_Assays_side_50000_Intensity_000
# 220228_KWC_35-52-97_simpleStimScreen_well2_side_50000_Intensity_000
# 220725_KWC_35-52-97_mcPak_Assays_side_50000_Intensity_002
# 220307_KWC_35-52-97_simpleStimScreen_side_50000_Intensity_004
# 220725_KWC_35-52-97_mcPak_Assays_side_50000_Intensity_006
# 220307_KWC_35-52-97_simpleStimScreen_side_50000_Intensity_001
# 220307_KWC_35-52-97_simpleStimScreen_side_50000_Intensity_000
# finding paths containing: "_front_"
#
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_011
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_005
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_000
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_009
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_017
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_014
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_000
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_007
# 220214_KWC_35-52-97_simpleStimScreen_front_50000_Intensity_001
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_013
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_002
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_003
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_009
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_008
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_001
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_008
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_007
# 220307_KWC_35-52-97_simpleStimScreen_front_50000_Intensity_000
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_012
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_001
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_018
# 220307_KWC_35-52-97_simpleStimScreen_front_50000_Intensity_001
# 220307_KWC_35-52-97_simpleStimScreen_front_50000_Intensity_004
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_015
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_011
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_000
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_005
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_012
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_003
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_006
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_006
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_001
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_002
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_012
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_010
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_013
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_010
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_007
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_008
# 220214_KWC_35-52-97_simpleStimScreen_front_50000_Intensity_000
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_011
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_002
# 220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_003
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_004
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_016
# finding paths containing: "_back_"
#
# 220725_KWC_35-52-97_mcPak_Assays_back_50000_Intensity_002
# 220228_KWC_35-52-97_simpleStimScreen_well2_back_50000_Intensity_000
# 220307_KWC_35-52-97_simpleStimScreen_back_50000_Intensity_005
# 220725_KWC_35-52-97_mcPak_Assays_back_50000_Intensity_005
# 220725_KWC_35-52-97_mcPak_Assays_back_50000_Intensity_000
# 220307_KWC_35-52-97_simpleStimScreen_back_50000_Intensity_000
# 220725_KWC_35-52-97_mcPak_Assays_back_50000_Intensity_006
# 220307_KWC_35-52-97_simpleStimScreen_back_50000_Intensity_004
# 220214_KWC_35-52-97_simpleStimScreen_back_50000_Intensity_000
# 220214_KWC_35-52-97_simpleStimScreen_back_50000_Intensity_001
# 220725_KWC_35-52-97_mcPak_Assays_back_50000_Intensity_001
# 220725_KWC_35-52-97_mcPak_Assays_back_50000_Intensity_004
# 220725_KWC_35-52-97_mcPak_Assays_back_50000_Intensity_007
# 220307_KWC_35-52-97_simpleStimScreen_back_50000_Intensity_001
# 220307_KWC_35-52-97_simpleStimScreen_back_50000_Intensity_002
# 220725_KWC_35-52-97_mcPak_Assays_back_50000_Intensity_003
# 220228_KWC_35-52-97_simpleStimScreen_back_50000_Intensity_000
# finding paths containing: "_global_"
#
# 220307_KWC_35-52-97_simpleStimScreen_global_50000_Intensity_000
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_014
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_010
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_012
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_005
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_015
# 220307_KWC_35-52-97_simpleStimScreen_global_50000_Intensity_004
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_003
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_008
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_001
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_000
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_002
# 220214_KWC_35-52-97_simpleStimScreen_global_50000_Intensity_000
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_012
# 220307_KWC_35-52-97_simpleStimScreen_global_50000_Intensity_002
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_002
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_005
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_011
# 220307_KWC_35-52-97_simpleStimScreen_global_50000_Intensity_001
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_015
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_010
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_006
# 220228_KWC_35-52-97_simpleStimScreen_well2_global_50000_Intensity_001
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_007
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_003
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_004
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_011
# 220228_KWC_35-52-97_simpleStimScreen_global_50000_Intensity_000
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_006
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_009
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_000
# 220307_KWC_35-52-97_simpleStimScreen_global_50000_Intensity_003
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_014
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_001
# 220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_004
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_007
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_016
# 220228_KWC_35-52-97_simpleStimScreen_well2_global_50000_Intensity_000
# 220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_017
# _none_ 50
# _side_ 15
# _front_ 45
# _back_ 17
# _global_ 39

# %% [markdown]
# # Figure S3A

# %%
different_conditions = ['_front_']

Pip_data = []
Rac_data = []

for condition in different_conditions:


    print(f'finding paths containing: "{condition}"' + '\n')
    
    # collect local list of paths to experiments to pool together for display
    exp_to_analyze = []
    
    for i in DATA:
        if (condition in i):
            num_img = len(os.listdir(i))
            if num_img >= 300:
                print(i, num_img)
                exp_to_analyze.append(i)


    ch0_rings = []
    ch1_rings = []
    ch2_rings = []

    for i in exp_to_analyze:
        try:
            a = simpleStimData(i)
            a.theta = a.theta
            a.get_angular_representation()

            if len(a.ch0_ring) >= 60:
                ch0_rings.append(a.ch0_ring[:60])
                ch1_rings.append(a.ch1_ring[:60])
                ch2_rings.append(a.ch2_ring[:60])
        except:
            pass

    A = np.nanmean(ch0_rings, axis = 0)
    B = np.nanmean(ch1_rings, axis = 0)
    C = np.nanmean(ch2_rings, axis = 0)

    plt.figure(figsize = (3., 3), dpi = 300)


    plt.subplot(131, aspect = 0.04)
    y = a.ch1_times- a.ch1_times[10]
    x = np.linspace(-math.pi, math.pi, 101)[:-1]
    x += (x[1] - x[0])/2 # center
    plt.pcolormesh(x, y, np.nanmean(ch2_rings, axis = 0), vmin = 500, vmax = 2500)
    plt.xticks([-math.pi, -math.pi/2, 0, math.pi/2, math.pi], ['-180°', '-90°', '0°', '90°', '180°'], fontsize = 8, rotation = 'vertical')
    plt.yticks([-60, 0, 60, 120, 180, 240, 300], fontsize = 8)
    plt.ylim(-60, 300)
    cbar = plt.colorbar(orientation = 'vertical', location = 'right', ticks = [500, 1500, 2500], shrink = 0.37)
    cbar.ax.tick_params(labelsize=6, rotation = 90)
    #plt.ylabel('Time (s)', fontsize = 8)


    plt.subplot(132, aspect = 0.04)
    y = a.ch1_times- a.ch1_times[10]
    x = np.linspace(-math.pi, math.pi, 101)[:-1]
    x += (x[1] - x[0])/2 # center
    plt.pcolormesh(x, y, np.nanmean(ch1_rings, axis = 0), vmin = 0.75, vmax = 1.4)
    plt.xticks([-math.pi, -math.pi/2, 0, math.pi/2, math.pi], ['-180°', '-90°', '0°', '90°', '180°'], fontsize = 8, rotation = 'vertical') #, -math.pi/2, 0, math.pi/2, math.pi]
    plt.yticks([-60, 0, 60, 120, 180, 240, 300], ['','','','','','',''], fontsize = 8)
    plt.ylim(-60, 300)
    cbar = plt.colorbar(orientation = 'vertical', location = 'right', ticks = [0.75, 1. , 1.25], shrink = 0.37)
    cbar.ax.tick_params(labelsize=6, rotation = 90)

    plt.subplot(133, aspect = 0.04)
    y = a.ch0_times- a.ch0_times[10]
    x = np.linspace(-math.pi, math.pi, 101)[:-1]
    x += (x[1] - x[0])/2 # center
    plt.pcolormesh(x, y, np.nanmean(ch0_rings, axis = 0), vmin = 0.5, vmax = 2)
    plt.xticks([-math.pi, -math.pi/2, 0, math.pi/2, math.pi], ['-180°', '-90°', '0°', '90°', '180°'], fontsize = 8, rotation = 'vertical')
    plt.yticks([-60, 0, 60, 120, 180, 240, 300], ['','','','','','',''], fontsize = 8)
    plt.ylim(-60, 300)
    plt.xlabel(' ')
    cbar = plt.colorbar(orientation = 'vertical', location = 'right', ticks = [0.5, 1, 1.5, 2], shrink = 0.37)
    cbar.ax.tick_params(labelsize=6, rotation = 90)
    plt.tight_layout()
    plt.show()
    
    Pip_data.append(ch1_rings)
    Rac_data.append(ch0_rings)
# Out:
# finding paths containing: "_front_"
#
# data/simpleStimData/220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_011 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_005 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_000 302
# data/simpleStimData/220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_009 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_017 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_014 302
# data/simpleStimData/220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_000 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_007 302
# data/simpleStimData/220214_KWC_35-52-97_simpleStimScreen_front_50000_Intensity_001 300
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_013 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_002 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_003 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_009 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_008 302
# data/simpleStimData/220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_001 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_008 302
# data/simpleStimData/220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_007 302
# data/simpleStimData/220307_KWC_35-52-97_simpleStimScreen_front_50000_Intensity_000 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_012 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_001 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_018 302
# data/simpleStimData/220307_KWC_35-52-97_simpleStimScreen_front_50000_Intensity_001 302
# data/simpleStimData/220307_KWC_35-52-97_simpleStimScreen_front_50000_Intensity_004 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_015 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_011 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_000 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_005 302
# data/simpleStimData/220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_012 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_003 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_006 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_006 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_001 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_002 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_012 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_010 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_013 302
# data/simpleStimData/220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_010 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_007 302
# data/simpleStimData/220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_008 302
# data/simpleStimData/220214_KWC_35-52-97_simpleStimScreen_front_50000_Intensity_000 300
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_011 302
# data/simpleStimData/220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_002 302
# data/simpleStimData/220628_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_003 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_004 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_front_50000_Intensity_016 302
# /home/jason/.local/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1113: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# /home/jason/.local/lib/python3.8/site-packages/scipy/ndimage/measurements.py:1406: RuntimeWarning: invalid value encountered in double_scalars
#   results = [sum(input * grids[dir].astype(float), labels, index) / normalizer

# %% [markdown]
# # Figure S3C

# %%
plt.figure(figsize = (2.5, 1.5), dpi = 300)
plt.axhline(1, color = 'k', ls = '--', zorder = -1)

baselines_0 = np.array([np.average(i[:10], axis = 0) for i in ch0_rings])
poststims_0 = np.array([np.average(i[10:20], axis = 0) for i in ch0_rings])


m = np.nanmean(poststims_0/baselines_0, axis = 0)
s = 1.968*np.nanstd(poststims_0/baselines_0, axis = 0)/np.sqrt(len(baselines_0))
plt.plot(x, m, c = 'C2')
plt.fill_between(x, m - s, m + s, alpha = 0.2, facecolor = 'C2')


    
baselines_1 = np.array([np.average(i[:10], axis = 0) for i in ch1_rings])
poststims_1 = np.array([np.average(i[10:20], axis = 0) for i in ch1_rings])

m = np.nanmean(poststims_1/baselines_1, axis = 0)
s = 1.968*np.nanstd(poststims_1/baselines_1, axis = 0)/np.sqrt(len(baselines_1))
plt.plot(x, m, c = 'C1')
plt.fill_between(x, m - s, m + s, alpha = 0.2, facecolor = 'C1')

plt.xlim(-math.pi, math.pi)
plt.xticks([-math.pi, -math.pi/2, 0, math.pi/2, math.pi], ['-180°', '-90°', '0°', '90°', '180°'], fontsize = 8, rotation = 'vertical')
plt.ylim(0.8, 1.6)
plt.yticks(fontsize = 8)
plt.show()

# %% [markdown]
# # Figure S3B

# %%
different_conditions = ['_global_']

Pip_data = []
Rac_data = []

for condition in different_conditions:


    print(f'finding paths containing: "{condition}"' + '\n')
    
    # collect local list of paths to experiments to pool together for display
    exp_to_analyze = []
    
    for i in DATA:
        if (condition in i):
            num_img = len(os.listdir(i))
            if num_img >= 300:
                print(i, num_img)
                exp_to_analyze.append(i)


    ch0_rings = []
    ch1_rings = []
    ch2_rings = []

    for i in exp_to_analyze:
        try:
            a = simpleStimData(i)
            a.theta = a.theta
            a.get_angular_representation()

            if len(a.ch0_ring) >= 60:
                ch0_rings.append(a.ch0_ring[:60])
                ch1_rings.append(a.ch1_ring[:60])
                ch2_rings.append(a.ch2_ring[:60])
        except:
            pass

    A = np.nanmean(ch0_rings, axis = 0)
    B = np.nanmean(ch1_rings, axis = 0)
    C = np.nanmean(ch2_rings, axis = 0)

    plt.figure(figsize = (3., 3), dpi = 300)


    plt.subplot(131, aspect = 0.04)
    y = a.ch1_times- a.ch1_times[10]
    x = np.linspace(-math.pi, math.pi, 101)[:-1]
    x += (x[1] - x[0])/2 # center
    plt.pcolormesh(x, y, np.nanmean(ch2_rings, axis = 0), vmin = 500, vmax = 2500)
    plt.xticks([-math.pi, -math.pi/2, 0, math.pi/2, math.pi], ['-180°', '-90°', '0°', '90°', '180°'], fontsize = 8, rotation = 'vertical')
    plt.yticks([-60, 0, 60, 120, 180, 240, 300], fontsize = 8)
    plt.ylim(-60, 300)
    cbar = plt.colorbar(orientation = 'vertical', location = 'right', ticks = [500, 1500, 2500], shrink = 0.37)
    cbar.ax.tick_params(labelsize=6, rotation = 90)
    #plt.ylabel('Time (s)', fontsize = 8)


    plt.subplot(132, aspect = 0.04)
    y = a.ch1_times- a.ch1_times[10]
    x = np.linspace(-math.pi, math.pi, 101)[:-1]
    x += (x[1] - x[0])/2 # center
    plt.pcolormesh(x, y, np.nanmean(ch1_rings, axis = 0), vmin = 0.75, vmax = 1.4)
    plt.xticks([-math.pi, -math.pi/2, 0, math.pi/2, math.pi], ['-180°', '-90°', '0°', '90°', '180°'], fontsize = 8, rotation = 'vertical') #, -math.pi/2, 0, math.pi/2, math.pi]
    plt.yticks([-60, 0, 60, 120, 180, 240, 300], ['','','','','','',''], fontsize = 8)
    plt.ylim(-60, 300)
    cbar = plt.colorbar(orientation = 'vertical', location = 'right', ticks = [0.75, 1. , 1.25], shrink = 0.37)
    cbar.ax.tick_params(labelsize=6, rotation = 90)

    plt.subplot(133, aspect = 0.04)
    y = a.ch0_times- a.ch0_times[10]
    x = np.linspace(-math.pi, math.pi, 101)[:-1]
    x += (x[1] - x[0])/2 # center
    plt.pcolormesh(x, y, np.nanmean(ch0_rings, axis = 0), vmin = 0.5, vmax = 2)
    plt.xticks([-math.pi, -math.pi/2, 0, math.pi/2, math.pi], ['-180°', '-90°', '0°', '90°', '180°'], fontsize = 8, rotation = 'vertical')
    plt.yticks([-60, 0, 60, 120, 180, 240, 300], ['','','','','','',''], fontsize = 8)
    plt.ylim(-60, 300)
    plt.xlabel(' ')
    cbar = plt.colorbar(orientation = 'vertical', location = 'right', ticks = [0.5, 1, 1.5, 2], shrink = 0.37)
    cbar.ax.tick_params(labelsize=6, rotation = 90)
    plt.tight_layout()
    plt.show()
    
    Pip_data.append(ch1_rings)
    Rac_data.append(ch0_rings)
# Out:
# finding paths containing: "_global_"
#
# data/simpleStimData/220307_KWC_35-52-97_simpleStimScreen_global_50000_Intensity_000 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_014 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_010 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_012 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_005 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_015 302
# data/simpleStimData/220307_KWC_35-52-97_simpleStimScreen_global_50000_Intensity_004 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_003 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_008 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_001 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_000 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_002 302
# data/simpleStimData/220214_KWC_35-52-97_simpleStimScreen_global_50000_Intensity_000 300
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_012 302
# data/simpleStimData/220307_KWC_35-52-97_simpleStimScreen_global_50000_Intensity_002 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_002 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_005 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_011 302
# data/simpleStimData/220307_KWC_35-52-97_simpleStimScreen_global_50000_Intensity_001 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_015 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_010 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_006 302
# data/simpleStimData/220228_KWC_35-52-97_simpleStimScreen_well2_global_50000_Intensity_001 300
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_007 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_003 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_004 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_011 302
# data/simpleStimData/220228_KWC_35-52-97_simpleStimScreen_global_50000_Intensity_000 300
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_006 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_009 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_000 302
# data/simpleStimData/220307_KWC_35-52-97_simpleStimScreen_global_50000_Intensity_003 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_014 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_001 302
# data/simpleStimData/220620_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_004 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_007 302
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_016 302
# data/simpleStimData/220228_KWC_35-52-97_simpleStimScreen_well2_global_50000_Intensity_000 300
# data/simpleStimData/220621_KWC_35-52-97_mcPak_VariousFrontStimulations_global_50000_Intensity_017 302
# /home/jason/.local/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1113: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# /home/jason/.local/lib/python3.8/site-packages/scipy/ndimage/measurements.py:1406: RuntimeWarning: invalid value encountered in double_scalars
#   results = [sum(input * grids[dir].astype(float), labels, index) / normalizer

# %% [markdown]
# # Figure S3D

# %%
plt.figure(figsize = (2.5, 1.5), dpi = 300)
plt.axhline(1, color = 'k', ls = '--', zorder = -1)

baselines_0 = np.array([np.average(i[:10], axis = 0) for i in ch0_rings])
poststims_0 = np.array([np.average(i[10:20], axis = 0) for i in ch0_rings])


m = np.nanmean(poststims_0/baselines_0, axis = 0)
s = 1.968*np.nanstd(poststims_0/baselines_0, axis = 0)/np.sqrt(len(baselines_0))
plt.plot(x, m, c = 'C2')
plt.fill_between(x, m - s, m + s, alpha = 0.2, facecolor = 'C2')


    
baselines_1 = np.array([np.average(i[:10], axis = 0) for i in ch1_rings])
poststims_1 = np.array([np.average(i[10:20], axis = 0) for i in ch1_rings])

m = np.nanmean(poststims_1/baselines_1, axis = 0)
s = 1.968*np.nanstd(poststims_1/baselines_1, axis = 0)/np.sqrt(len(baselines_1))
plt.plot(x, m, c = 'C1')
plt.fill_between(x, m - s, m + s, alpha = 0.2, facecolor = 'C1')

plt.xlim(-math.pi, math.pi)
plt.xticks([-math.pi, -math.pi/2, 0, math.pi/2, math.pi], ['-180°', '-90°', '0°', '90°', '180°'], fontsize = 8, rotation = 'vertical')
plt.ylim(0.8, 1.6)
plt.yticks(fontsize = 8)
plt.show()
